# %% [markdown]
# Considere o dataset sobre câncer de mama abaixo

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/fbarth/ml-espm/master/data/breast-cancer-wisconsin-tratado.csv"
s=requests.get(url).content
df=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
print(df.shape)
df.head()
# Out:
# (569, 31)
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave.points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# Implemente os seguintes itens:
#
# 1. Selecione aleatoriamente 20% do dataset para teste final. Só utilize este dataset para avaliar os três modelos escolhidos.
# 2. Implemente um modelo usando árvore de decisão. Execute diversas vezes o algoritmo indutor de árvore de decisão variando a profundidade das árvores. Para avaliar qual é a melhor profundidade utilize o método de cross-validation.
# 3. Implemente um modelo usando Knn. Execute diversas vezes o algoritmo Knn variando o k. Para avaliar qual é o melhor K utilize o método de cross-validation.
# 4. Implemente um modelo usando RandomForest. Execute diversas vezes o algoritmo RandomForest variando: (i) quantidade de árvores; (ii) profundidade das árvores, e; (iii) quantidade de atributos considerados por árvore. Para avaliar qual é a melhor configuração utilize o OOB.
# 5. Faça um último teste com o melhor modelo de árvore de decisão, knn e RandomForest utilizando o conjunto de teste final.
# 6. Apresente as acurácias e matriz de confusão obtidos por cada modelo.
