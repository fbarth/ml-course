# %%
import pandas as pd
df = pd.read_csv('../../data/BeijingMultiSiteAirQuality/PRSA_Data_Wanliu_20130301-20170228.csv')

# %%
df = df[['PM2.5','CO','TEMP','PRES','RAIN']]

# %%
df.head()
# Out:
#    PM2.5     CO  TEMP    PRES  RAIN
# 0    8.0  400.0  -0.7  1023.0   0.0
# 1    9.0  400.0  -1.1  1023.2   0.0
# 2    3.0  400.0  -1.1  1023.5   0.0
# 3   11.0    NaN  -1.4  1024.5   0.0
# 4    3.0  300.0  -2.0  1025.2   0.0

# %%
df.corr(method ='pearson')
# Out:
#           PM2.5        CO      TEMP      PRES      RAIN
# PM2.5  1.000000  0.749722 -0.133353  0.005119 -0.012699
# CO     0.749722  1.000000 -0.401004  0.228898 -0.020365
# TEMP  -0.133353 -0.401004  1.000000 -0.827683  0.036736
# PRES   0.005119  0.228898 -0.827683  1.000000 -0.060896
# RAIN  -0.012699 -0.020365  0.036736 -0.060896  1.000000

# %%
import matplotlib.pyplot as plt
df.plot(kind='scatter', x='CO', y='PM2.5', style='o')
df.plot(kind='scatter', x='TEMP', y='PM2.5', style='o')
df.plot(kind='scatter', x='PRES', y='PM2.5', style='o')
df.plot(kind='scatter', x='RAIN', y='PM2.5', style='o')

# %%
df['CO'].plot(kind='hist')

# %%
df['TEMP'].plot(kind='hist')

# %%
df['PRES'].plot(kind='hist')

# %%
df['RAIN'].plot(kind='hist')

# %%
df['PM2.5'].plot(kind='hist')

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler() 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df))
df_scaled = df_scaled.rename(columns={0: 'PM2.5', 1: 'CO', 2: 'TEMP', 3: 'PRES', 4: 'RAIN'})

# %%
df_scaled.head()
# Out:
#       PM2.5        CO      TEMP      PRES  RAIN
# 0  0.006283  0.030303  0.268206  0.681985   0.0
# 1  0.007330  0.030303  0.261101  0.685662   0.0
# 2  0.001047  0.030303  0.261101  0.691176   0.0
# 3  0.009424       NaN  0.255773  0.709559   0.0
# 4  0.001047  0.020202  0.245115  0.722426   0.0

# %%
import matplotlib.pyplot as plt
df_scaled.plot(kind='scatter', x='CO', y='PM2.5', style='o')
df_scaled.plot(kind='scatter', x='TEMP', y='PM2.5', style='o')
df_scaled.plot(kind='scatter', x='PRES', y='PM2.5', style='o')
df_scaled.plot(kind='scatter', x='RAIN', y='PM2.5', style='o')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(
